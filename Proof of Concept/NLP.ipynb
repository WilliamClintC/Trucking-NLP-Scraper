# %%
import pandas as pd

df_significant_words = pd.read_csv('significant_words.csv')

# %%
df_significant_words
# Out:
#                 Word  Frequency
# 0                OTR       1588
# 1                DOT       1309
# 2              hours        856
# 3              Swift        655
# 4         California        528
# ...              ...        ...
# 76444          Tesia          1
# 76445       (Freight          1
# 76446  Championship)          1
# 76447    Overbearing          1
# 76448   helplessness          1
#
# [76449 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

top_20_words = df_significant_words.head(20)
plt.figure(figsize=(12, 6))
plt.bar(top_20_words['Word'], top_20_words['Frequency'])
plt.xlabel('Word')
plt.ylabel('Frequency')
plt.title('Top 30 Words')
plt.xticks(rotation=45, ha='right')
plt.show()
