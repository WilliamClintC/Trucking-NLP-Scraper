# %%
import pandas as pd

labelled_df_do = pd.read_csv('labelled_df_do.csv')

# %%
labelled_df_do
# Out:
#         Unnamed: 0                                               Text  \
# 0                0  Truck drivers of reddit. How many miles do you...
# 1                1               Was just granted modship of this sub
# 2                2                                      Trucking wiki
# 3                3       Truck with asphalt sealant tipped over today
# 4                4  a Grand Prairie Police officer walked away fro...
# ...            ...                                                ...
# 163746      163746  Found this at a Virginia Rest stop. If anyone ...
# 163747      163747                        Which one of y'all is this
# 163748      163748  Billion Dollar Business Idea (Freight Fighting...
# 163749      163749               Overbearing feeling of helplessness
# 163750      163750  Bit of an oops happened right before I needed ...
#
#                                                Embeddings  Predicted Label
# ...

# %%
filtered_df = labelled_df_do[labelled_df_do['Predicted Label'] == 1]
filtered_df
# Out:
#         Unnamed: 0                                               Text  \
# 145            145                                GPS recommendations
# 233            233     What's the best paying load you have ever had?
# 287            287                          Best cell carrier for OTR
# 377            377     What's the best paying load you have ever run?
# 547            547  PA turnpike exit 110 is a good place to shutdo...
# ...            ...                                                ...
# 163637      163637  Anyone have good food recommendations with tru...
# 163638      163638  Anyone have any good food spot recommendations...
# 163681      163681                  What do you guys eat on the road?
# 163700      163700                        wildest trucking stories ?
# 163734      163734               Are international trucks bad trucks?
#
#                                                Embeddings  Predicted Label
# ...

# %%
filtered_df.to_csv('filtered_df.csv', index=False)
