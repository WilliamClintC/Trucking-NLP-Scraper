# %%
import pandas as pd

df_significant_words = pd.read_csv('significant_words.csv')
df_significant_words
# Out:
#                 Word  Frequency
# 0                OTR       1588
# 1                DOT       1309
# 2              hours        856
# 3              Swift        655
# 4         California        528
# ...              ...        ...
# 76444          Tesia          1
# 76445       (Freight          1
# 76446  Championship)          1
# 76447    Overbearing          1
# 76448   helplessness          1
#
# [76449 rows x 2 columns]

# %%
# Define the "locations" variable
locations = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming', 'Alberta', 'British Columbia', 'Manitoba', 'New Brunswick', 'Newfoundland and Labrador', 'Northwest Territories', 'Nova Scotia', 'Nunavut', 'Ontario', 'Prince Edward Island', 'Quebec', 'Saskatchewan', 'Yukon']

# Handle NaN values in the dataframe
df_significant_words.fillna('', inplace=True)

# Apply the filtering operation
filtered_df = df_significant_words.loc[df_significant_words['Word'].str.contains('|'.join(locations))]

# %%
filtered_df
# Out:
#                  Word  Frequency
# 4          California        528
# 12              Texas        477
# 100           Florida        287
# 176           Wyoming        228
# 257              Ohio        195
# ...               ...        ...
# 76031  Massachusetts)          1
# 76046      (Delaware)          1
# 76227      (Kentucky)          1
# 76300      Louisiana!          1
# 76384       "Arkansas          1
#
# [518 rows x 2 columns]

# %%
# Out:
# ...
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.3 MB 640.0 kB/s eta 0:00:10
#    - -------------------------------------- 0.2/6.3 MB 2.6 MB/s eta 0:00:03
#    -- ------------------------------------- 0.4/6.3 MB 3.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.7/6.3 MB 4.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.9/6.3 MB 4.5 MB/s eta 0:00:02
#    ------ --------------------------------- 1.1/6.3 MB 3.9 MB/s eta 0:00:02
#    --------- ------------------------------ 1.5/6.3 MB 4.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.8/6.3 MB 5.0 MB/s eta 0:00:01
#    ------------- -------------------------- 2.1/6.3 MB 5.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.6/6.3 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.5/6.3 MB 11.1 MB/s eta 0:00:01
# ...
